# %%
import redcap
import pandas as pd
data = {
    'token': '085520489DF98911614E03FF05D58EA8',
    'content': 'project',
    'format': 'csv',
    'returnFormat': 'csv'
}

df= redcap.Project('https://ruff.mrc.gm:8443/redcap/api/', data['token'])

# %%
ironsupplement=df.export_records(forms=['ironsupplement'])
serumstorage=df.export_records(forms=['serumstorage'])
hepcidineresults=df.export_records(forms=['hepcidineresults'])
randomization=df.export_records(forms=['randomization'])
g6pd_819c16=df.export_records(forms=['g6pd_819c16'])
withdrawal=df.export_records(forms=['withdrawal'])
bloodsample_processing=df.export_records(forms=['bloodsample_processing'])
feedingquestionaire=df.export_records(forms=['feedingquestionaire'])
sourcedocument=df.export_records(forms=['sourcedocument'])
erythroferroneresult=df.export_records(forms=['erythroferroneresult'])
demograhics=df.export_records(forms=['demograhics'])
stoolstorage=df.export_records(forms=['stoolstorage'])
bloodsamplecollection=df.export_records(forms=['bloodsamplecollection'])
posthealthmonitoring=df.export_records(forms=['posthealthmonitoring'])
calprotectin=df.export_records(forms=['calprotectin'])
ip_accountability_log=df.export_records(forms=['ip_accountability_log'])
vitalsign=df.export_records(forms=['vitalsign'])
samplereception=df.export_records(forms=['samplereception'])
sysmexresult=df.export_records(forms=['sysmexresult'])
screening=df.export_records(forms=['screening'])
assessment_of_informed_consent_understanding=df.export_records(forms=['assessment_of_informed_consent_understanding'])
anthrops=df.export_records(forms=['anthrops'])
ae=df.export_records(forms=['ae'])
stoolsamplecollection=df.export_records(forms=['stoolsamplecollection'])
consent=df.export_records(forms=['consent'])
clinicreferal=df.export_records(forms=['clinicreferal'])
ironpanel1=df.export_records(forms=['ironpanel1'])
intervention=df.export_records(forms=['intervention'])
noncompliance_form=df.export_records(forms=['noncompliance_form'])
g6pd=df.export_records(forms=['g6pd_819c16'])
stool_processing=df.export_records(forms=['stool_processing'])
prescreening=df.export_records(forms=['prescreening'])
erythroferroneresult_2=df.export_records(forms=['erythroferroneresult_2'])

# %%
#ironsupplement
ironsupplement=pd.DataFrame(ironsupplement)
ironsupplement=ironsupplement[
    (ironsupplement['ironsupplement_complete']=='2')
]
ironsupplement.to_excel('ironsupplement.xlsx',index=False)

#serumstorage
serumstorage=pd.DataFrame(serumstorage)
serumstorage=serumstorage[
    (serumstorage['serumstorage_complete']=='2')
]
serumstorage.to_excel('serumstorage.xlsx',index=False)

#hepcidineresults
hepcidineresults=pd.DataFrame(hepcidineresults)
hepcidineresults=hepcidineresults[
    (hepcidineresults['hepcidineresults_complete']=='2')
]
hepcidineresults.to_excel('hepcidineresults.xlsx',index=False)

#randomization
randomization=pd.DataFrame(randomization)
randomization=randomization[
    (randomization['randomization_complete']=='2')
]
randomization.to_excel('randomization.xlsx',index=False)

#g6pd_819c16
g6pd_819c16=pd.DataFrame(g6pd_819c16)
g6pd_819c16=g6pd_819c16[
    (g6pd_819c16['g6pd_819c16_complete']=='2')
]
g6pd_819c16.to_excel('G6PD.xlsx',index=False)

#withdrawal
withdrawal=pd.DataFrame(withdrawal)
withdrawal=withdrawal[
    (withdrawal['withdrawal_complete']=='2')
]
withdrawal.to_excel('withdrawal.xlsx',index=False)

#bloodsample_processing
bloodsample_processing=pd.DataFrame(bloodsample_processing)
bloodsample_processing=bloodsample_processing[
    (bloodsample_processing['bloodsample_processing_complete']=='2')
]
bloodsample_processing.to_excel('bloodsample_processing.xlsx',index=False)

#feedingquestionaire
feedingquestionaire=pd.DataFrame(feedingquestionaire)
feedingquestionaire=feedingquestionaire[
    (feedingquestionaire['feedingquestionaire_complete']=='2')
]
feedingquestionaire.to_excel('feedingquestionaire.xlsx',index=False)

#sourcedocument
sourcedocument=pd.DataFrame(sourcedocument)
sourcedocument=sourcedocument[
    (sourcedocument['sourcedocument_complete']=='2')
]
sourcedocument.to_excel('sourcedocument.xlsx',index=False)

#erythroferroneresult
erythroferroneresult=pd.DataFrame(erythroferroneresult)
erythroferroneresult=erythroferroneresult[
    (erythroferroneresult['erythroferroneresult_complete']=='2')
]
erythroferroneresult.to_excel('EPO.xlsx',index=False)

#demograhics
demograhics=pd.DataFrame(demograhics)
demograhics=demograhics[
    (demograhics['demograhics_complete']=='2')
]
demograhics.to_excel('demograhics.xlsx',index=False)

#stoolstorage
stoolstorage=pd.DataFrame(stoolstorage)
stoolstorage=stoolstorage[
    (stoolstorage['stoolstorage_complete']=='2')
]
stoolstorage.to_excel('stoolstorage.xlsx',index=False)

#bloodsamplecollection
bloodsamplecollection=pd.DataFrame(bloodsamplecollection)
bloodsamplecollection=bloodsamplecollection[
    (bloodsamplecollection['bloodsamplecollection_complete']=='2')
]
bloodsamplecollection.to_excel('bloodsamplecollection.xlsx',index=False)

#posthealthmonitoring
posthealthmonitoring=pd.DataFrame(posthealthmonitoring)
posthealthmonitoring=posthealthmonitoring[
    (posthealthmonitoring['posthealthmonitoring_complete']=='2')
]
posthealthmonitoring.to_excel('posthealthmonitoring.xlsx',index=False)

#calprotectin
calprotectin=pd.DataFrame(calprotectin)
calprotectin=calprotectin[
    (calprotectin['calprotectin_complete']=='2')
]
calprotectin.to_excel('calprotectin.xlsx',index=False)

#ip_accountability_log
ip_accountability_log=pd.DataFrame(ip_accountability_log)
ip_accountability_log=ip_accountability_log[
    (ip_accountability_log['ip_accountability_log_complete']=='2')
]
ip_accountability_log.to_excel('ip_accountability_log.xlsx',index=False)

#vitalsign
vitalsign=pd.DataFrame(vitalsign)
vitalsign=vitalsign[
    (vitalsign['vitalsign_complete']=='2')
]
vitalsign.to_excel('vitalsign.xlsx',index=False)

#samplereception
samplereception=pd.DataFrame(samplereception)
samplereception=samplereception[
    (samplereception['samplereception_complete']=='2')
]
samplereception.to_excel('samplereception.xlsx',index=False)

#sysmexresult
sysmexresult=pd.DataFrame(sysmexresult)
sysmexresult=sysmexresult[
    (sysmexresult['sysmexresult_complete']=='2')
]
sysmexresult.to_excel('sysmexresult.xlsx',index=False)

#screening
screening=pd.DataFrame(screening)
screening=screening[
    (screening['screening_complete']=='2')
]
screening.to_excel('screening.xlsx',index=False)

#assessment_of_informed_consent_understanding
assessment_of_informed_consent_understanding=pd.DataFrame(assessment_of_informed_consent_understanding)
assessment_of_informed_consent_understanding=assessment_of_informed_consent_understanding[
    (assessment_of_informed_consent_understanding['assessment_of_informed_consent_understanding_complete']=='2')
]
assessment_of_informed_consent_understanding.to_excel('assessment_of_informed_consent_understanding.xlsx',index=False)

#anthrops
anthrops=pd.DataFrame(anthrops)
anthrops=anthrops[
    (anthrops['anthrops_complete']=='2')
]
anthrops.to_excel('anthrops.xlsx',index=False)

#ae
ae=pd.DataFrame(ae)
ae=ae[
    (ae['ae_complete']=='2')
]
ae.to_excel('AE.xlsx',index=False)

#stoolsamplecollection
stoolsamplecollection=pd.DataFrame(stoolsamplecollection)
stoolsamplecollection=stoolsamplecollection[
    (stoolsamplecollection['stoolsamplecollection_complete']=='2')
]
stoolsamplecollection.to_excel('stoolsamplecollection.xlsx',index=False)

#consent
consent=pd.DataFrame(consent)
consent=consent[
    (consent['consent_complete']=='2')
]
consent.to_excel('consent.xlsx',index=False)

#clinicreferal
clinicreferal=pd.DataFrame(clinicreferal)
clinicreferal=clinicreferal[
    (clinicreferal['clinicreferal_complete']=='2')
]
clinicreferal.to_excel('clinicreferal.xlsx',index=False)

#ironpanel1
ironpanel1=pd.DataFrame(ironpanel1)
ironpanel1=ironpanel1[
    (ironpanel1['ironpanel1_complete']=='2')
]
ironpanel1.to_excel('ironpanel.xlsx',index=False)

#intervention
intervention=pd.DataFrame(intervention)
intervention=intervention[
    (intervention['intervention_complete']=='2')
]
intervention.to_excel('intervention.xlsx',index=False)

#noncompliance_form
noncompliance_form=pd.DataFrame(noncompliance_form)
noncompliance_form=noncompliance_form[
    (noncompliance_form['noncompliance_form_complete']=='2')
]
noncompliance_form.to_excel('noncompliance_form.xlsx',index=False)

#g6pd
g6pd=pd.DataFrame(g6pd)
g6pd=g6pd[
    (g6pd['g6pd_819c16_complete']=='2')
]
g6pd.to_excel('G6PD.xlsx',index=False)

#stool_processing
stool_processing=pd.DataFrame(stool_processing)
stool_processing=stool_processing[
    (stool_processing['stool_processing_complete']=='2')
]
stool_processing.to_excel('stool_processing.xlsx',index=False)

#prescreening
prescreening=pd.DataFrame(prescreening)
prescreening=prescreening[
    (prescreening['prescreening_complete']=='2')
]
prescreening.to_excel('prescreening.xlsx',index=False)

#erythroferroneresult_2
erythroferroneresult_2=pd.DataFrame(erythroferroneresult_2)
erythroferroneresult_2=erythroferroneresult_2[
    (erythroferroneresult_2['erythroferroneresult_2_complete']=='2')
]
erythroferroneresult_2.to_excel('Erythroferroneresult.xlsx',index=False)
