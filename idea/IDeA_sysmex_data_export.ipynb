# %%
import json
import redcap
import pandas as pd
import pyodbc
data = {
    'token': '085520489DF98911614E03FF05D58EA8',
    'content': 'project',
    'format': 'csv',
    'returnFormat': 'csv'
}

proj= redcap.Project('https://ruff.mrc.gm:8443/redcap/api/', data['token'])

# %%
with open('config.json') as config_file:
    config = json.load(config_file)
username = config['username']
password = config['password']
server = config['server']
database = config['database']
driver = config['driver']
cnxn = pyodbc.connect(f"Driver={driver};Server={server};Database={database};uid={username};pwd={password};Trusted_Connection=yes;")

# %%
#visit one sysmex data

#complete_sysmex=proj.export_records(forms=['sysmexresult'])
#complete_sysmex=pd.DataFrame(complete_sysmex)
#complete_sysmex=complete_sysmex
#[
  #  (complete_sysmex['sysmexresult_complete']=='2') &
    #(complete_sysmex['redcap_event_name']=='v1_arm_1')

#]

# Retrieve all records from the source

#sql_query = "SELECT * FROM vw_IDeA_sysmex"  
#sysmexresult_data = pd.read_sql(sql_query, cnxn)

# Filter out completed form IDs from your data
#sysmexresult_data = sysmexresult_data[~sysmexresult_data['cons_recordid_q1'].isin(complete_sysmex)]

#sysmexresult_data['sysmexresult_complete'] = 2
#records_to_import = sysmexresult_data.to_dict('records')
#event_name = 'v1_arm_1'

#for record in records_to_import:
 #   record['redcap_event_name'] = event_name

#response = proj.import_records(records_to_import, return_content='ids', overwrite=False)  # do not allow overiding

# Check if the response contains any errors
#if 'error' in response:
  #  print("There was an error in importing the data.")
#else:
 #   print("Data has been successfully imported.")

# %%
#visit 12 sysmex_data

sql_query = "SELECT * FROM dbo.vw_IDeA_sysmex_v12"
sysmexresult_data = pd.read_sql(sql_query, cnxn)
sysmexresult_data['sysmexresult_complete'] = 2
records_to_import = sysmexresult_data.to_dict('records')
event_name = 'v12_arm_1'  
for record in records_to_import:
    record['redcap_event_name'] = event_name

response = proj.import_records(records_to_import, return_content='ids', overwrite=False)

# Check if the response contains any errors
if 'error' in response:
    print("There was an error in importing the data.")
else:
    print("Data has been successfully imported.")
# Out:
# C:\Users\abliebah\AppData\Local\Temp\ipykernel_16036\1701125155.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sysmexresult_data = pd.read_sql(sql_query, cnxn)
# ---------------------------------------------------------------------------
# RequestException                          Traceback (most recent call last)
# Cell In[28], line 11
#       8 for record in records_to_import:
#       9     record['redcap_event_name'] = event_name
# ---> 11 response = proj.import_records(records_to_import, return_content='ids', overwrite=False)
#      13 # Check if the response contains any errors
#      14 if 'error' in response:
#
# File c:\Users\abliebah\AppData\Local\Programs\Python\Python311\Lib\site-packages\redcap\methods\records.py:430, in Records.import_records(self, to_import, return_format_type, return_content, overwrite, import_format, date_format, force_auto_number)
#     423 payload["forceAutoNumber"] = force_auto_number
#     425 return_type = self._lookup_return_type(
#     426     format_type=return_format_type,
#     427     request_type="import",
#     428     import_records_format=return_content,
#     429 )
# --> 430 response = self._call_api(payload, return_type)
#     432 return response
#
# File c:\Users\abliebah\AppData\Local\Programs\Python\Python311\Lib\site-packages\redcap\methods\base.py:515, in Base._call_api(self, payload, return_type, file)
#     512 return_headers = return_type == "file_map"
#     514 rcr = _RCRequest(url=self.url, payload=payload, config=config)
# --> 515 return rcr.execute(
#     516     verify_ssl=self.verify_ssl, return_headers=return_headers, file=file
#     517 )
#
# File c:\Users\abliebah\AppData\Local\Programs\Python\Python311\Lib\site-packages\redcap\request.py:224, in _RCRequest.execute(self, verify_ssl, return_headers, file)
#     221     bad_request = "<error>" in str(content).lower()
#     223 if bad_request:
# --> 224     raise RedcapError(content)
#     226 if return_headers:
#     227     return content, response.headers
#
# RequestException: {'error': '"IDEA30192G","sysm_wbc_q1","11.82","This field is located on a form that is locked. You must first unlock this form for this record."\n"IDEA30192G","sysm_rbc_q2","5.09","This field is located on a form that is locked. You must first unlock this form for this record."\n"IDEA30192G","sysm_hgb_q3","11.5","This field is located on a form that is locked. You must first unlock this form for this record."\n"IDEA30192G","sysm_htc_q4","35.7","This field is located on a form that is locked. You must first unlock this form for this record."\n"IDEA30192G","sysm_mcv_q5","70.1","This field is located on a form that is locked. You must first unlock this form for this record."\n"IDEA30192G","sysm_mch_q6","22.6","This field is located on a form that is locked. You must first unlock this form for this record."\n"IDEA30192G","sysm_mchc_q7","32.2","This field is located on a form that is locked. You must first unlock this form for this record."\n"IDEA30192G","sysm_plt_q8","747","This field is located on a form that is locked. You must first unlock this form for this record."\n"IDEA30192G","sysm_rwd_sd_q9","44.6","This field is located on a form that is locked. You must first unlock this form for this record."\n"IDEA30192G","sysm_rwd_cv_q10","18.3","This field is located on a form that is locked. You must first unlock this form for this record."\n"IDEA30192G","sysm_pdw_q11","10.5","This field is located on a form that is locked. You must first unlock this form for this record."\n"IDEA30192G","sysm_mpv_q12","9.9","This field is located on a form that is locked. You must first unlock this form for this record."\n"IDEA30192G","sysm_p_lcr_q13","23.5","This field is located on a form that is locked. You must first unlock this form for this record."\n"IDEA30192G","sysm_pct_q14","0.74","This field is located on a form that is locked. You must first unlock this form for this record."\n"IDEA30192G","sysm_neut_q15","1.29","This field is located on a form that is locked. You must first unlock this form for this record."\n"IDEA30192G","sysm_lymph_q16","9.14","This field is located on a form that is locked. You must first unlock this form for this record."\n"IDEA30192G","sysm_mono_q17","0.78","This field is located on a form that is locked. You must first unlock this form for this record."\n"IDEA30192G","sysm_eo_q18","0.56","This field is located on a form that is locked. You must first unlock this form for this record."\n"IDEA30192G","sysm_baso_q19","0.05","This field is located on a form that is locked. You must first unlock this form for this record."\n"IDEA30192G","sysm_neut_percent_q20","11.0","This field is located on a form that is locked. You must first unlock this form for this record."\n"IDEA30192G","sysm_lymph_percent_q21","77.3","This field is located on a form that is locked. You must first unlock this form for this record."\n"IDEA30192G","sysm_mono_percent_q22","6.6","This field is located on a form that is locked. You must first unlock this form for this record."\n"IDEA30192G","sysm_eo_percent_q23","4.7","This field is located on a form that is locked. You must first unlock this form for this record."\n"IDEA30192G","sysm_baso_percent_q24","0.4","This field is located on a form that is locked. You must first unlock this form for this record."\n"IDEA30192G","sysm_ig_q25","0.02","This field is located on a form that is locked. You must first unlock this form for this record."\n"IDEA30192G","sysm_ig_percent_q26","0.2","This field is located on a form that is locked. You must first unlock this form for this record."\n"IDEA30192G","sysm_micror_q27","28.9","This field is located on a form that is locked. You must first unlock this form for this record."\n"IDEA30192G","sysm_macror_q28","3.2","This field is located on a form that is locked. You must first unlock this form for this record."\n"IDEA30192G","sysm_ret_q29","0.0769","This field is located on a form that is locked. You must first unlock this form for this record."\n ...
